# %%
# !pip install optuna
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.10/dist-packages (4.1.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (1.14.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.36)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (1.3.8)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)

# %% [markdown]
# #**Entendendo o negócio**
#
# **Sobre os dados:** Esses dados apresentam informações sobre pessoas que buscaram um cartão de crédito. Nele temos diversos tipos de dados como categórico binário, quantitativo discreto, quantitativo contínuo e categórico nominal.
#
# **Objetivo:** Fazer a previsão de quais pessoas conseguem aprovação do cartão de crédito e a retirada de possíveis ações para busca de mais candidatos.
#
# **Fluxo do projeto:**
# - Entendendo o negócio
# - Entendendo os dados
# - Análise da distribuição dos dados
# - Pré-processamento
# - Modelagem
#   - Comparação dos modelos e escolha do que possui melhor desempenho
#   - Ajustando o modelo com hiper-parâmetros
# - Avaliação
#   - Avaliar o modelo com as métricas
# - Resultados Financeiros
#
# .
#
# **Dataset:** https://www.kaggle.com/datasets/samuelcortinhas/credit-card-approval-clean-data?resource=download

# %% [markdown]
# #**Entendendo os dados**

# %% [markdown]
# Importação das bibliotecas que serão utilizadas ao decorrer do projeto.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import optuna
import seaborn as sns

from sklearn.preprocessing import LabelEncoder

from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split, cross_val_score, cross_validate, GridSearchCV, StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import make_scorer, accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix, roc_auc_score, brier_score_loss, roc_curve, precision_recall_curve, auc, ConfusionMatrixDisplay
from imblearn.over_sampling import SMOTE

# %% [markdown]
# Definindo algumas configurações globais para os gráficos.

# %%
# %matplotlib inline

mpl.style.use('ggplot')

mpl.rcParams['axes.facecolor']      = 'white'
mpl.rcParams['axes.linewidth']      = 1
mpl.rcParams['xtick.color']         = 'black'
mpl.rcParams['ytick.color']         = 'black'
mpl.rcParams['grid.color']          = 'lightgray'
mpl.rcParams['figure.dpi']          = 100
mpl.rcParams['axes.grid']           = True
mpl.rcParams['font.size']           = 12

# %% [markdown]
# Importação dos dados que iremos utilizar.

# %%
dados = '/content/clean_dataset.csv'
df = pd.read_csv(dados)

# %%
df.head()
# Out:
#    Gender    Age   Debt  Married  BankCustomer     Industry Ethnicity  \
# 0       1  30.83  0.000        1             1  Industrials     White
# 1       0  58.67  4.460        1             1    Materials     Black
# 2       0  24.50  0.500        1             1    Materials     Black
# 3       1  27.83  1.540        1             1  Industrials     White
# 4       1  20.17  5.625        1             1  Industrials     White
#
#    YearsEmployed  PriorDefault  Employed  CreditScore  DriversLicense  \
# 0           1.25             1         1            1               0
# 1           3.04             1         1            6               0
# 2           1.50             1         0            0               0
# 3           3.75             1         1            5               1
# 4           1.71             1         0            0               0
#
#         Citizen  ZipCode  Income  Approved
# 0       ByBirth      202       0         1
# 1       ByBirth       43     560         1
# 2       ByBirth      280     824         1
# 3       ByBirth      100       3         1
# 4  ByOtherMeans      120       0         1

# %% [markdown]
# ###**Dicionário dos dados:**
# - **Gender:** Gênero do cliente, 0 = mulher e 1 = homem. Categórico binário.
# - **Age:** Idade do cliente. Quantitativo discreto.
# - **Debt:** Valor da dívida atual do cliente. Quantitativo contínuo.
# - **Married:** Estado civil, 0 = Solteiro/Divorciado/etc, 1 = Casado. Categórico binário.
# - **BankCustomer:** Indica se ele é um cliente bancário, 1 = tem uma conta bancária, 0 = não tem um conta. Categórico binário.
# - **Industry:** Setor do emprego do cliente. Categorica Nominal.
# - **Ethnicity:** Grupo étnico na qual o cliente pertence. Categórico binário.
# - **YearsEmployed:** Quantidade de anos que o cliente esta empregado. Quantitativo discreto.
# - **PriorDefault:** Histórico de inadimplência em pagamentos anteriores. 0 = incumprimento anterior, 1 = cumprimento anterior. Categórico binário.
# - **Employed:** Status de emprego atual do cliente. 1 = empregado, 0 = desempregado. Categórico binário.
# - **CreditScore:** Pontução de crédito. Quantitativo discreto.
# - **DriversLicense:** Indica se o cliente possui uma carteira de motorista válida. 1 = possui carteira, 0 = não possui carteira. Categórico binário.
# - **Citizen:**  Status de cidadania. Categórica nominal.
# - **ZipCode:** Código postal da residencia. Categórico nominal.
# - **Income:** Renda anual do cliente. Quantitativo contínuo.
# - **Approved:** Status de aprovação para o cartão de crédito, 1 = aprovado, 0 = não aprovado. Categórico binário.

# %%
print(f'O DataFrame possui {df.shape[0]} linhas e {df.shape[1]} colunas')
# Out:
# O DataFrame possui 690 linhas e 16 colunas

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          690 non-null    int64
#  1   Age             690 non-null    float64
#  2   Debt            690 non-null    float64
#  3   Married         690 non-null    int64
#  4   BankCustomer    690 non-null    int64
#  5   Industry        690 non-null    object
#  6   Ethnicity       690 non-null    object
#  7   YearsEmployed   690 non-null    float64
#  8   PriorDefault    690 non-null    int64
#  9   Employed        690 non-null    int64
#  10  CreditScore     690 non-null    int64
#  11  DriversLicense  690 non-null    int64
#  12  Citizen         690 non-null    object
#  13  ZipCode         690 non-null    int64
#  14  Income          690 non-null    int64
#  15  Approved        690 non-null    int64
# dtypes: float64(3), int64(10), object(3)
# memory usage: 86.4+ KB

# %%
df.describe().T
# Out:
#                 count         mean          std    min     25%     50%  \
# Gender          690.0     0.695652     0.460464   0.00   0.000    1.00
# Age             690.0    31.514116    11.860245  13.75  22.670   28.46
# Debt            690.0     4.758725     4.978163   0.00   1.000    2.75
# Married         690.0     0.760870     0.426862   0.00   1.000    1.00
# BankCustomer    690.0     0.763768     0.425074   0.00   1.000    1.00
# YearsEmployed   690.0     2.223406     3.346513   0.00   0.165    1.00
# PriorDefault    690.0     0.523188     0.499824   0.00   0.000    1.00
# Employed        690.0     0.427536     0.495080   0.00   0.000    0.00
# CreditScore     690.0     2.400000     4.862940   0.00   0.000    0.00
# DriversLicense  690.0     0.457971     0.498592   0.00   0.000    0.00
# ZipCode         690.0   180.547826   173.970323   0.00  60.000  160.00
# Income          690.0  1017.385507  5210.102598   0.00   0.000    5.00
# Approved        690.0     0.444928     0.497318   0.00   0.000    0.00
#
#                      75%        max
# Gender            1.0000       1.00
# Age              37.7075      80.25
# Debt              7.2075      28.00
# Married           1.0000       1.00
# BankCustomer      1.0000       1.00
# YearsEmployed     2.6250      28.50
# PriorDefault      1.0000       1.00
# Employed          1.0000       1.00
# CreditScore       3.0000      67.00
# DriversLicense    1.0000       1.00
# ZipCode         272.0000    2000.00
# Income          395.5000  100000.00
# Approved          1.0000       1.00

# %% [markdown]
# - É possível visualizar que a maioria dos dados se refere ao gênero masculino.
# - Na idade mostra uma grande variedade, sendo de adolecentes de 13 anos até idosos de 80. Porém boa parte das pessoas possuem entre 22 e 37 anos.
# - Nas dívidas percebemos que a médiana esta em 2.75 e o valor máximo é 28. Isso mostra que boa parte das pessoas possuem dividas baixas.
# - A maioria dos indivíduos são casados.
# - Uma grande parte já são clientes regulares de banco.
# - Nos anos empregrados concluímos com base nos quartis que muitos estão em empregos recentes.
# - Um pouco mais da média não teve inadinplencia anterior.
# - Há uma proporção negativa, levando em consideração a quantidade de pessoas que não estão empregadas.
# - Levando em consideração a escala de crédito na qual inicia em 0 e seu máximo é 67, boa parte das pessoas possuem créditos baixos.
# - Menos da metade das pessoas possuem carteira de habilitação.
# - Há uma grande desigualdade nas rendas, tendo um desvio padrão de 5210, enquanto a média de salários fica em 1017 o máximo registrado é de 100.000.
# - Apenas cerca de 44% dos participantes foram aprovados.

# %%
numericos_com_bool = df.select_dtypes('number').columns.tolist()
numericos = [col for col in numericos_com_bool if df[col].nunique() > 2]
booleanos = [col for col in numericos_com_bool if df[col].nunique() < 3]
categoricos = df.select_dtypes('object').columns.tolist()
objetivo = 'Approved'

print(f"Há {len(numericos)} dados numéricos, sendo eles:")
print(numericos)
print(f"\nHá {len(booleanos)} dados booleanos, sendo eles:")
print(booleanos)
print(f"\nHá {len(categoricos)} dados categóricos, sendo eles:")
print(categoricos)
print(f"\nVariável alvo:")
print(objetivo)
# Out:
# Há 6 dados numéricos, sendo eles:
# ['Age', 'Debt', 'YearsEmployed', 'CreditScore', 'ZipCode', 'Income']
#
# Há 7 dados booleanos, sendo eles:
# ['Gender', 'Married', 'BankCustomer', 'PriorDefault', 'Employed', 'DriversLicense', 'Approved']
#
# Há 3 dados categóricos, sendo eles:
# ['Industry', 'Ethnicity', 'Citizen']
#
# Variável alvo:
# Approved

# %%
for elemento in categoricos:
  print(elemento)
  print('-'*40)
  print(f'Há {df[elemento].nunique()} valores únicos, sendo eles:')
  print(f'{df[elemento].value_counts(normalize=True)}\n')
# Out:
# Industry
# ----------------------------------------
# Há 14 valores únicos, sendo eles:
# Industry
# Energy                   0.211594
# Materials                0.113043
# Industrials              0.092754
# ConsumerDiscretionary    0.085507
# ConsumerStaples          0.078261
# Healthcare               0.076812
# Financials               0.073913
# InformationTechnology    0.059420
# CommunicationServices    0.055072
# Utilities                0.055072
# Real Estate              0.043478
# Education                0.036232
# Research                 0.014493
# Transport                0.004348
# Name: proportion, dtype: float64
#
# Ethnicity
# ----------------------------------------
# Há 5 valores únicos, sendo eles:
# Ethnicity
# White     0.591304
# Black     0.200000
# Asian     0.085507
# Latino    0.082609
# Other     0.040580
# Name: proportion, dtype: float64
#
# Citizen
# ----------------------------------------
# Há 3 valores únicos, sendo eles:
# Citizen
# ByBirth         0.905797
# ByOtherMeans    0.082609
# Temporary       0.011594
# Name: proportion, dtype: float64

# %% [markdown]
# ##**Análise da distribuição dos dados**
# Iremos fazer uma análise de cada um dos dados separadamente para compreendermos como é sua distribuição.
#
# Abaixo estaremos observando como esta o balanceamento da nossa variável alvo.

# %%
approved = df['Approved'].value_counts(normalize=True)
approved_df = approved.reset_index()
approved_df.columns = ['Approved', 'Proportion']
approved_df['Proportion'] = approved_df['Proportion'].apply(lambda x: x * 100)

sns.set_theme(style='darkgrid')
fig, ax = plt.subplots(figsize=(5, 4))
bars = sns.barplot(data=approved_df, x='Approved', y='Proportion', ax=ax)
ax.set_xticks(ticks=range(2), labels=['Não aprovado', 'Aprovado'], fontsize=10.5)
ax.set_ylabel('Proporção')
ax.set_xlabel('')
ax.set_title('Balanceamento da variável Approved', fontsize=13, fontweight='bold', pad=15, loc='left')

colors = ['#DB7093', '#7B68EE']
for i, bar in enumerate(ax.patches):
  bar.set_facecolor(colors[i])

for bar in bars.containers[0]:
  height = bar.get_height()
  ax.annotate('{:.1f}%'.format(height),
              xy=(bar.get_x() + bar.get_width() / 2, height),
              xytext=(0, -10),
              textcoords="offset points",
              ha='center', va='center',
              fontsize=11, color='white')

plt.show()

# %% [markdown]
# Os dados não estão completamente desbalanceados, mas existe uma leve predominancia dos não aprovados. Nesse caso temos um balanceamento moderado e aceitável.

# %% [markdown]
# analisar a possibilidade de aplicar técnicas para aumentar a classe de aprovados. Oversampling: SMOTE (Synthetic Minority Over-sampling Technique) é uma técnica comum.

# %% [markdown]
# ###**Distribuição numérica**
#
# Abaixo temos gráficos histogramas que apresetam a distribuição dos dados das colunas numéricas.

# %%
num_plots = len(numericos)
rows = (num_plots // 3) + (1 if num_plots % 3 != 0 else 0)

fig, ax = plt.subplots(rows, 3, figsize=(13, 4 * rows))
ax = ax.flatten()

for i, coluna in enumerate(numericos):
    sns.histplot(data=df, x=coluna, ax=ax[i], bins=25, color='#DC143C')
    ax[i].set_title(f'Distribuição da coluna\n{coluna}', fontsize=15)
    ax[i].set_xlabel(coluna, fontsize=13)
    ax[i].set_ylabel('Quantidade', fontsize=13)

for i in range(len(numericos), len(ax)):
    fig.delaxes(ax[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# Abaixo estamos apenas dando um zoom, definindo os limites para focar na parte densa dos dados para melhor visualização.

# %%
num_plots = len(numericos)
rows = (num_plots // 3) + (1 if num_plots % 3 != 0 else 0)
fig, ax = plt.subplots(2, 3, figsize=(13, 4 * rows))
ax = ax.flatten()

for i, coluna in enumerate(numericos):
    sns.histplot(data=df, x=coluna, ax=ax[i], bins=25, color='#DC143C')
    ax[i].set_title(f'Distribuição da coluna\n{coluna}', fontsize=15)
    ax[i].set_xlabel(coluna, fontsize=13)
    ax[i].set_ylabel('Quantidade', fontsize=13)

    ax[i].set_xlim(df[coluna].quantile(0.01), df[coluna].quantile(0.99))

plt.tight_layout()
plt.show()

# %%
num_plots = len(numericos)
rows = (num_plots // 3) + (1 if num_plots % 3 != 0 else 0)

fig, ax = plt.subplots(rows, 3, figsize=(13, 4 * rows))
ax = ax.flatten()

for i, coluna in enumerate(numericos):
    sns.boxplot(data=df, x=coluna, ax=ax[i], color='#DC143C')
    ax[i].set_title(f'Distribuição da coluna\n{coluna}', fontsize=15)
    ax[i].set_xlabel(coluna, fontsize=13)
    ax[i].set_ylabel('Quantidade', fontsize=13)

for i in range(len(numericos), len(ax)):
    fig.delaxes(ax[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# ###**Observações das distribuições dos dados numéricos.**
# - A maioria dos indivíduos estão na faixa de 20 a 60 anos de idade com uma mediana abaixo de 40 anos mostrando uma faixa de idade jovem. Também mostrando um pico significativo na faixa dos 20 ao 30 anos.
# - A distribuição dos valores da dívida é assimétrica mostrando uma grande quantidade de valores baixos.
# - A maioria das pessoas esta empregada por menos de 5 anos, reforçando que a maioria são pessoas jovens que estão iniciando a carreira.
# - Com a maioria dos indicadores de crédito baixo, podem ajudar a explicar as dívidas elevadas e a concentração na baixa renda.

# %% [markdown]
# ###**Distribuição categórica**

# %%
if 'Approved' in booleanos:
    booleanos.remove('Approved')

num_plots = len(categoricos) + len(booleanos)
dist = list(categoricos) + list(booleanos)
rows = (num_plots // 3) + (1 if num_plots % 3 != 0 else 0)

fig, ax = plt.subplots(rows, 3, figsize=(15, 3.5 * rows))
ax = ax.flatten()
fig.suptitle('Distribuição das colunas categóricas e booleanas', fontsize=18, y=1.005, fontweight='bold')
plt.subplots_adjust(hspace=0.6, wspace=0.4)

for i, coluna in enumerate(categoricos):
    counts = df[coluna].value_counts(normalize=True) * 100
    sns.barplot(y=counts.index, x=counts.values, ax=ax[i], color='#DC143C')
    ax[i].set_title(coluna, fontsize=15)
    ax[i].set_ylabel('Classes', fontsize=13)
    ax[i].set_xlabel('Densidade (%)', fontsize=13)
    for p in ax[i].patches:
        ax[i].annotate(format(p.get_width(), '.1f'),
                       (p.get_width(), p.get_y() + p.get_height() / 2.),
                       ha='center', va='center',
                       xytext=(14, 0),
                       textcoords='offset points',
                       color='black')

for i, coluna in enumerate(booleanos):
    counts = df[coluna].value_counts(normalize=True) * 100
    sns.barplot(x=counts.index, y=counts.values, ax=ax[i + len(categoricos)], color='#DC143C')
    ax[i + len(categoricos)].set_title(coluna, fontsize=15)
    ax[i + len(categoricos)].set_xlabel('Classes', fontsize=13)
    ax[i + len(categoricos)].set_ylabel('Densidade (%)', fontsize=13)
    for p in ax[i + len(categoricos)].patches:
        ax[i + len(categoricos)].annotate(format(p.get_height(), '.1f'),
                                          (p.get_x() + p.get_width() / 2., p.get_height()),
                                          ha='center', va='center',
                                          xytext=(0, -12),
                                          textcoords='offset points',
                                          color='white')

# Remover subplots vazios, caso tiver
for i in range(len(dist), len(ax)):
    fig.delaxes(ax[i])

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %% [markdown]
# ###**Observações das distribuições dos dados categóricos.**
#
# - A maioria das pessoas trabalham em uma industria de energia, materiais e industrias.
# - Boa parte das pessoas se identificam com a etnica branca.
# - Com uma grande concentração de 90% os status de cidadania é por nascimento.
# - A distribuição de gênero tem uma predominancia de homens.
# - Grande parte já são casados, talvez indicando uma estabilidade financeira.
# - Uma certa quantidade já são clientes de um banco, sendo positivo para entendermos melhor a situação fiananceira.
# - Há um certo equilibrio entre as pessoas que possuem e as que não possuem inadimplencia.
# - A maioria das pessoas estão empregadas, o que apresenta uma certa estabilidade de renda.

# %% [markdown]
# ###**Correlação dos dados**

# %% [markdown]
# Primeiro iremos fazer a conversão das variáveis categóricas para as numéricas.

# %%
label_encoder = LabelEncoder()
df_com_le = df.copy()

for coluna in categoricos:
    df_com_le[coluna] = label_encoder.fit_transform(df[coluna])

# %% [markdown]
# Para fazer a matriz de correlação iremos utilizar o método de Spearman, pois ela não é eficaz somente para relações lineares sendo útil quando estamos lidando com variáveis categóricas e contínuas. Com ela temos uma menor sensibilidade dos outliers em comparação ao Pearson.
#
# Estarei usando como base que correlações com valores acima de 0.5 são fortes, de 0.3 a 0.5 são moderadas.

# %%
correlacao = df_com_le.corr(numeric_only=True, method='spearman')
mascara = np.triu(np.ones_like(correlacao, dtype=bool))

plt.figure(figsize=(16, 12))
sns.heatmap(correlacao, mask=mascara, annot=True, cmap='BuPu', fmt='.2f', linewidths=1, vmin=-1, vmax=1)
plt.title('Matriz de Correlação', fontsize=15, fontweight='bold')
plt.show()

# %% [markdown]
# - Diretamente em relação a variável alvo (Approved), podemos ver que uma forte influencia é o PriorDefault (Inadimplência) com 0.72, indicando que caso a pessoa já tiver um histórico de inadimplência ela é menos favoravel para receber a aprovação.
# - Outro influenciador principal é a prontuação de crédito, assim como o status de emprego atual do indivíduo e a quantidade de anos que a pessoa esta empregada.
# - A pontuação de crédito é influenciada principalmente pelo status de emprego e se a pessoa já teve casos de inadimplencia.
# - Podemos perceber que boa parte das pessoas com inadimplência são influenciada por pessoas empregadas.

# %% [markdown]
# ###**Observando como a aprovação esta distribuida nos setores de trabalho**
#
# Com isso podemos observar em qual setor temos mais aprovações, o que pode nos trazer ações futuras para incentivo nessas áreas.

# %%
approval_counts = df.groupby(['Industry', 'Approved']).size().unstack(fill_value=0)

approval_counts.reset_index(inplace=True)

fig, ax = plt.subplots(figsize=(14, 7))
bar_width = 0.35
bar_positions = np.arange(len(approval_counts))

bars_approved = ax.bar(bar_positions, approval_counts[1], bar_width, label='Aprovado', color=colors[0])
bars_not_approved = ax.bar(bar_positions + bar_width, approval_counts[0], bar_width, label='Não Aprovado', color=colors[1])

ax.set_xlabel('Setor de Trabalho')
ax.set_ylabel('Quantidade')
ax.set_title('Distribuição de Aprovação de Crédito por Setor de Trabalho', fontsize=16, pad=15, fontweight='bold')
ax.set_xticks(bar_positions + bar_width / 2)
ax.set_xticklabels(approval_counts['Industry'], rotation=45, ha='right')
ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ###**Principais observações**
#
# - A maioria dos indivíduos que estão buscando crédito são jovens que estão no inicio da carreia profissional, o que também da sentido aos valores baixos de renda. Com isso apresenta a possibilidade da instituição financeira desenvolver produtos de crédito especifico para jovens profissionais, com possibilidades de juros mais baixo e ofertas que ajudem no inicio de carreira.
# - A maioria da amostra é composta por cidadãos natos e com emprego, possivelmente em setores específicos, e por isso poderiam ser concentradas as campanhas de marketing em áreas com forte empregabilidade, como por exemplo o setor de energia e materiais.
# - A predominancia de clientes bancários sugere uma oportunidade de estratégias para inclusão financeira. Uma parceria e programas que visem a minoria e grupos que possuem menos acesso a serviços bancários, com imprestimos mais favorais a essas pessoas.
# - A pontuação de crédito é influenciada pelo status de emprego atual e pela sua duração, e incluindo programas de transição de carreita pode beneficiar a instituição para aumentar a base de clientes com melhor capacidade de pagamento.
# - Com a alta inadimplencia observada, é interessante realizar uma análise para identificar os sinais precoces de inadimplência.

# %% [markdown]
# #**Pré-processamento dos dados**
#
# ###**Sepração dos dados em treinamento e teste**
#
# - Essa sepração serve para que os dados de teste do modelo não tenha sido visto anteriormente, fazendo com que tenhamos mais certeza que a avaliação é justa e precisa.
# - Com isso também também fazemos uma prevensão de overfitting, evitando que o modelo se ajuste aos dados apresentados e generalise os novos.
# - Será usado o 'stratify' para que os dados de treinamento e teste mantenham a mesma proporção da variável alvo, pois sem a estratificação é possivel que uma das classes fique subrepresentada no conjunto de teste ou treinamento.
# - Como os dados possui um breve desbalanceamento, resolvi utilizar o SMOTE para conseguir mais dados com base nos já existentes, levando em consideração que a temos uma quantidade relativamente baixa para uma boa precisão.

# %%
scaler = MinMaxScaler()
df_com_le[numericos + categoricos] = scaler.fit_transform(df_com_le[numericos + categoricos])

X = df_com_le.drop('Approved', axis=1)
y = df_com_le['Approved'].copy()

# %%
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

print("Dados antes do SMOTE:", X.shape)
print("Dados após o SMOTE:", X_resampled.shape)

X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42, stratify=y_resampled)
# Out:
# Dados antes do SMOTE: (690, 15)
# Dados após o SMOTE: (766, 15)
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_tags.py:354: FutureWarning: The SMOTE or classes from which it inherits use `_get_tags` and `_more_tags`. Please define the `__sklearn_tags__` method, or inherit from `sklearn.base.BaseEstimator` and/or other appropriate mixins such as `sklearn.base.TransformerMixin`, `sklearn.base.ClassifierMixin`, `sklearn.base.RegressorMixin`, and `sklearn.base.OutlierMixin`. From scikit-learn 1.7, not defining `__sklearn_tags__` will raise an error.
#   warnings.warn(

# %% [markdown]
# Com o objetivo de verificar se os dados foram separados corretamente mantendo a distribuição, estarei verificando o shape das variáveis.

# %%
print(f'X train: {X_train.shape}.')
print(f'y train: {y_train.shape}.')
print(f'X test: {X_test.shape}.')
print(f'y train: {y_test.shape}.')
# Out:
# X train: (612, 15).
# y train: (612,).
# X test: (154, 15).
# y train: (154,).

# %% [markdown]
# **Estaremos Utilizando os seguintes modelos:**
#
# - Regressão logística: Simples de interpretar e implementar.
# - Árvore de decisão: Fácil de interpretar e não requer normalização dos dados e é bom para detectar relações não lineares.
# - Random forest: Reduz a probabilidade de overfitting, lida bem com dados categóricos e numéricos.
#
# **Também utilizaremos as seguintes métricas de avaliação:**
#
# - Acurácia: Ela mede a proporção de previsões corretas tantos positivas quanto negativas.
# - F1: É uma média harmônica entre precisão e recall, balanceando a necessidade de ambos.

# %% [markdown]
# #**Treinamento para comparação dos modelos**
#
# Abaixo estaremos fazendo um treinamento simples usando a validação cruzada para a visualização da avaliação de cada modelo, com isso será escolhido um deles para o aprimoramento aplicando hiperparâmetros.

# %%
tree_models = {
    'Regressão Logística': LogisticRegression(class_weight='balanced', random_state=30),
    'Random Forest': RandomForestClassifier(class_weight='balanced', random_state=30),
    'Decision Tree': DecisionTreeClassifier(class_weight='balanced', random_state=30)
}

# %% [markdown]
# Abaixo estamos criando uma função para o treinamento com a validação cruzada, como iremos fazer o processo com alguns modelos, dessa forma fica mais fácil de compreender.

# %%
def classification_kfold_cv(models, X_train, y_train, n_folds=5):
    results = []
    for model_name, model in models.items():

        scoring = {
            'accuracy': 'accuracy',
            'precision': make_scorer(precision_score),
            'recall': make_scorer(recall_score),
            'f1': make_scorer(f1_score)
        }

        scores = cross_val_score(model, X_train, y_train, cv=n_folds, scoring='accuracy')
        precision_scores = cross_val_score(model, X_train, y_train, cv=n_folds, scoring=scoring['precision'])
        recall_scores = cross_val_score(model, X_train, y_train, cv=n_folds, scoring=scoring['recall'])
        f1_scores = cross_val_score(model, X_train, y_train, cv=n_folds, scoring=scoring['f1'])

        results.append({
            'model': model_name,
            'avg_val_score': scores.mean(),
            'f1': f1_scores.mean(),
            'train_score': model.fit(X_train, y_train).score(X_train, y_train)
        })
    return pd.DataFrame(results)

# %% [markdown]
# Abaixo estamos criando uma função para a plotagem do gráfico de comparação dos modelos treinados.

# %%
def plot_classification_kfold_cv(df, bar_width=0.35, figsize=(9, 4), title_size=14, legend_x=0.175, legend_y=1.2, title_pad=50):
    df = df.set_index('model')
    ax = df[['avg_val_score', 'f1', 'train_score']].plot(kind='bar', figsize=figsize, width=bar_width)
    ax.set_title('K-Fold Cross Validation Scores', fontsize=title_size, pad=title_pad)
    ax.set_ylabel('Score')
    ax.set_xlabel('Model')
    plt.legend(loc='upper center', bbox_to_anchor=(legend_x, legend_y))
    plt.xticks(rotation=45)
    plt.show()

# %%
eval_df = classification_kfold_cv(models=tree_models,
                                  X_train=X_train,
                                  y_train=y_train,
                                  n_folds=5)

plot_classification_kfold_cv(eval_df, bar_width=0.35, figsize=(9, 4), title_size=14, legend_x=0.175, legend_y=1.2, title_pad=50)

eval_df
# Out:
#                  model  avg_val_score        f1  train_score
# 0  Regressão Logística       0.851193  0.858113     0.866013
# 1        Random Forest       0.862628  0.862351     1.000000
# 2        Decision Tree       0.812009  0.816319     1.000000

# %% [markdown]
# Visualizando as métricas que foram avaliadas dos modelos, irei escolher o Random Forest por ter um equilibrio e um valor maior na acurácia e no f1.

# %% [markdown]
# #**Ajustando os hiperparâmetros do modelo escolhido**

# %% [markdown]
# Agora iremos ajustar os hiperparâmetros com o objetivo de otimizar o modelo e maximizar seu potencial, além disso conseguimos uma prevenção de overfitting e underfitting, sendo importante levando em consideração que anteriormente a pontuação de treino deu 1, indicando um possível overfitting. Ajustar o modelo melhora o tempo e os recursos adicionais.
#
# Abaixo estou utilizando o optuna que é uma ferramenta de otimização de hiperparâmetros, com o objetivo de encontrar os melhores parâmetros de forma eficiênte, economizando tempo.

# %%
def objective_random_forest(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 10, 500),
        'max_depth': trial.suggest_int('max_depth', 2, 32, log=True),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 16),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 16),
        'bootstrap': trial.suggest_categorical('bootstrap', [True, False]),
        'max_features': trial.suggest_categorical('max_features', ['sqrt', 'log2', None]),
        'criterion': trial.suggest_categorical('criterion', ['gini', 'entropy']),
        'min_impurity_decrease': trial.suggest_float('min_impurity_decrease', 0.0, 0.1)
    }

    model = RandomForestClassifier(**params)
    stratified_kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    val_scores = cross_val_score(model, X_train, y_train, scoring='f1', cv=stratified_kfold)
    avg_f1_score = np.mean(val_scores)
    return avg_f1_score

study_random_forest = optuna.create_study(direction='maximize')

study_random_forest.optimize(objective_random_forest, n_trials=100)

best_params_random_forest = study_random_forest.best_params
best_score_random_forest = study_random_forest.best_value

print("Random Forest - Melhores Hiperparâmetros:", best_params_random_forest)
print("Random Forest - Melhor F1 Score:", best_score_random_forest)
# Out:
# [I 2025-01-03 15:57:56,013] A new study created in memory with name: no-name-10ef7802-185d-42ac-8062-85357a98a7cc
# [I 2025-01-03 15:58:06,414] Trial 0 finished with value: 0.8651745497825202 and parameters: {'n_estimators': 386, 'max_depth': 4, 'min_samples_split': 14, 'min_samples_leaf': 10, 'bootstrap': True, 'max_features': None, 'criterion': 'gini', 'min_impurity_decrease': 0.032577706173316866}. Best is trial 0 with value: 0.8651745497825202.
# [I 2025-01-03 15:58:06,871] Trial 1 finished with value: 0.8651745497825202 and parameters: {'n_estimators': 16, 'max_depth': 27, 'min_samples_split': 12, 'min_samples_leaf': 10, 'bootstrap': False, 'max_features': None, 'criterion': 'entropy', 'min_impurity_decrease': 0.094950953794039}. Best is trial 0 with value: 0.8651745497825202.
# [I 2025-01-03 15:58:14,247] Trial 2 finished with value: 0.8651745497825202 and parameters: {'n_estimators': 320, 'max_depth': 25, 'min_samples_split': 13, 'min_samples_leaf': 12, 'bootstrap': True, 'max_features': None, 'criterion': 'gini', 'min_impurity_decrease': 0.07304046713808253}. Best is trial 0 with value: 0.8651745497825202.
# [I 2025-01-03 15:58:17,784] Trial 3 finished with value: 0.8543583441737461 and parameters: {'n_estimators': 209, 'max_depth': 3, 'min_samples_split': 7, 'min_samples_leaf': 11, 'bootstrap': False, 'max_features': 'log2', 'criterion': 'gini', 'min_impurity_decrease': 0.08472303439072487}. Best is trial 0 with value: 0.8651745497825202.
# [I 2025-01-03 15:58:20,702] Trial 4 finished with value: 0.8579994715360992 and parameters: {'n_estimators': 149, 'max_depth': 5, 'min_samples_split': 7, 'min_samples_leaf': 12, 'bootstrap': False, 'max_features': 'log2', 'criterion': 'entropy', 'min_impurity_decrease': 0.04849200582358252}. Best is trial 0 with value: 0.8651745497825202.
# [I 2025-01-03 15:58:22,977] Trial 5 finished with value: 0.8529445650322371 and parameters: {'n_estimators': 78, 'max_depth': 28, 'min_samples_split': 6, 'min_samples_leaf': 8, 'bootstrap': False, 'max_features': None, 'criterion': 'entropy', 'min_impurity_decrease': 0.01582129352308096}. Best is trial 0 with value: 0.8651745497825202.
# [I 2025-01-03 15:58:28,171] Trial 6 finished with value: 0.8600790407124427 and parameters: {'n_estimators': 376, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 7, 'bootstrap': False, 'max_features': 'log2', 'criterion': 'gini', 'min_impurity_decrease': 0.07825442083798093}. Best is trial 0 with value: 0.8651745497825202.
# [I 2025-01-03 15:58:28,701] Trial 7 finished with value: 0.8492480633935697 and parameters: {'n_estimators': 23, 'max_depth': 21, 'min_samples_split': 8, 'min_samples_leaf': 12, 'bootstrap': True, 'max_features': 'log2', 'criterion': 'gini', 'min_impurity_decrease': 0.09423105824804119}. Best is trial 0 with value: 0.8651745497825202.
# [I 2025-01-03 15:58:32,224] Trial 8 finished with value: 0.8596150837680032 and parameters: {'n_estimators': 174, 'max_depth': 28, 'min_samples_split': 11, 'min_samples_leaf': 13, 'bootstrap': False, 'max_features': 'sqrt', 'criterion': 'gini', 'min_impurity_decrease': 0.027858916190032026}. Best is trial 0 with value: 0.8651745497825202.
# [I 2025-01-03 15:58:40,568] Trial 9 finished with value: 0.8623834397715575 and parameters: {'n_estimators': 427, 'max_depth': 2, 'min_samples_split': 6, 'min_samples_leaf': 6, 'bootstrap': True, 'max_features': 'log2', 'criterion': 'entropy', 'min_impurity_decrease': 0.07443292132523263}. Best is trial 0 with value: 0.8651745497825202.
# [I 2025-01-03 15:58:52,137] Trial 10 finished with value: 0.8731466999825285 and parameters: {'n_estimators': 481, 'max_depth': 11, 'min_samples_split': 16, 'min_samples_leaf': 2, 'bootstrap': True, 'max_features': 'sqrt', 'criterion': 'gini', 'min_impurity_decrease': 0.0002348658472376211}. Best is trial 10 with value: 0.8731466999825285.
# [I 2025-01-03 15:59:04,027] Trial 11 finished with value: 0.867424859686389 and parameters: {'n_estimators': 495, 'max_depth': 11, 'min_samples_split': 16, 'min_samples_leaf': 1, 'bootstrap': True, 'max_features': 'sqrt', 'criterion': 'gini', 'min_impurity_decrease': 0.0010792951621411903}. Best is trial 10 with value: 0.8731466999825285.
# [I 2025-01-03 15:59:15,429] Trial 12 finished with value: 0.877175653724597 and parameters: {'n_estimators': 485, 'max_depth': 11, 'min_samples_split': 16, 'min_samples_leaf': 1, 'bootstrap': True, 'max_features': 'sqrt', 'criterion': 'gini', 'min_impurity_decrease': 0.002771715023592327}. Best is trial 12 with value: 0.877175653724597.
# [I 2025-01-03 15:59:27,345] Trial 13 finished with value: 0.8725032174881735 and parameters: {'n_estimators': 489, 'max_depth': 10, 'min_samples_split': 16, 'min_samples_leaf': 1, 'bootstrap': True, 'max_features': 'sqrt', 'criterion': 'gini', 'min_impurity_decrease': 0.0014002179799839016}. Best is trial 12 with value: 0.877175653724597.
# [I 2025-01-03 15:59:32,851] Trial 14 finished with value: 0.861779906220318 and parameters: {'n_estimators': 287, 'max_depth': 13, 'min_samples_split': 14, 'min_samples_leaf': 4, 'bootstrap': True, 'max_features': 'sqrt', 'criterion': 'gini', 'min_impurity_decrease': 0.022925757272412826}. Best is trial 12 with value: 0.877175653724597.
# [I 2025-01-03 15:59:42,138] Trial 15 finished with value: 0.8634827951384931 and parameters: {'n_estimators': 433, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 4, 'bootstrap': True, 'max_features': 'sqrt', 'criterion': 'gini', 'min_impurity_decrease': 0.04644336413172407}. Best is trial 12 with value: 0.877175653724597.
# [I 2025-01-03 15:59:48,731] Trial 16 finished with value: 0.873710887037513 and parameters: {'n_estimators': 339, 'max_depth': 16, 'min_samples_split': 16, 'min_samples_leaf': 3, 'bootstrap': True, 'max_features': 'sqrt', 'criterion': 'gini', 'min_impurity_decrease': 0.012741894511569584}. Best is trial 12 with value: 0.877175653724597.
# [I 2025-01-03 15:59:58,018] Trial 17 finished with value: 0.875255295032167 and parameters: {'n_estimators': 353, 'max_depth': 17, 'min_samples_split': 14, 'min_samples_leaf': 16, 'bootstrap': True, 'max_features': 'sqrt', 'criterion': 'gini', 'min_impurity_decrease': 0.012648150726017137}. Best is trial 12 with value: 0.877175653724597.
# [I 2025-01-03 16:00:02,967] Trial 18 finished with value: 0.8651212519385514 and parameters: {'n_estimators': 252, 'max_depth': 18, 'min_samples_split': 14, 'min_samples_leaf': 15, 'bootstrap': True, 'max_features': 'sqrt', 'criterion': 'entropy', 'min_impurity_decrease': 0.059282063143661634}. Best is trial 12 with value: 0.877175653724597.
# [I 2025-01-03 16:00:12,306] Trial 19 finished with value: 0.8621580414607983 and parameters: {'n_estimators': 422, 'max_depth': 7, 'min_samples_split': 3, 'min_samples_leaf': 16, 'bootstrap': True, 'max_features': 'sqrt', 'criterion': 'gini', 'min_impurity_decrease': 0.03682381945152916}. Best is trial 12 with value: 0.877175653724597.
# [I 2025-01-03 16:00:19,666] Trial 20 finished with value: 0.8738377561740869 and parameters: {'n_estimators': 346, 'max_depth': 14, 'min_samples_split': 12, 'min_samples_leaf': 14, 'bootstrap': True, 'max_features': 'sqrt', 'criterion': 'gini', 'min_impurity_decrease': 0.012581811459860742}. Best is trial 12 with value: 0.877175653724597.
# [I 2025-01-03 16:00:27,198] Trial 21 finished with value: 0.8719763760288084 and parameters: {'n_estimators': 351, 'max_depth': 15, 'min_samples_split': 12, 'min_samples_leaf': 14, 'bootstrap': True, 'max_features': 'sqrt', 'criterion': 'gini', 'min_impurity_decrease': 0.013201347700983572}. Best is trial 12 with value: 0.877175653724597.
# [I 2025-01-03 16:00:33,322] Trial 22 finished with value: 0.8651314736609871 and parameters: {'n_estimators': 288, 'max_depth': 9, 'min_samples_split': 14, 'min_samples_leaf': 16, 'bootstrap': True, 'max_features': 'sqrt', 'criterion': 'gini', 'min_impurity_decrease': 0.019260625218014204}. Best is trial 12 with value: 0.877175653724597.
# [I 2025-01-03 16:00:38,840] Trial 23 finished with value: 0.8748488404379536 and parameters: {'n_estimators': 242, 'max_depth': 20, 'min_samples_split': 10, 'min_samples_leaf': 14, 'bootstrap': True, 'max_features': 'sqrt', 'criterion': 'gini', 'min_impurity_decrease': 0.00802788315755984}. Best is trial 12 with value: 0.877175653724597.
# [I 2025-01-03 16:00:43,668] Trial 24 finished with value: 0.8799526844610203 and parameters: {'n_estimators': 243, 'max_depth': 21, 'min_samples_split': 10, 'min_samples_leaf': 6, 'bootstrap': True, 'max_features': 'sqrt', 'criterion': 'gini', 'min_impurity_decrease': 0.007954109350970642}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:00:47,648] Trial 25 finished with value: 0.8686886164736578 and parameters: {'n_estimators': 160, 'max_depth': 23, 'min_samples_split': 15, 'min_samples_leaf': 6, 'bootstrap': True, 'max_features': 'sqrt', 'criterion': 'gini', 'min_impurity_decrease': 0.03907561445109159}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:00:54,204] Trial 26 finished with value: 0.8725292820167787 and parameters: {'n_estimators': 308, 'max_depth': 12, 'min_samples_split': 9, 'min_samples_leaf': 5, 'bootstrap': True, 'max_features': 'sqrt', 'criterion': 'entropy', 'min_impurity_decrease': 0.02686828974221377}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:00:58,326] Trial 27 finished with value: 0.8673899802209629 and parameters: {'n_estimators': 213, 'max_depth': 32, 'min_samples_split': 4, 'min_samples_leaf': 8, 'bootstrap': True, 'max_features': 'sqrt', 'criterion': 'gini', 'min_impurity_decrease': 0.058437826991877544}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:01:11,255] Trial 28 finished with value: 0.8767363830791173 and parameters: {'n_estimators': 452, 'max_depth': 16, 'min_samples_split': 13, 'min_samples_leaf': 9, 'bootstrap': True, 'max_features': None, 'criterion': 'gini', 'min_impurity_decrease': 0.00842925028396212}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:01:24,381] Trial 29 finished with value: 0.8778393638796788 and parameters: {'n_estimators': 452, 'max_depth': 8, 'min_samples_split': 11, 'min_samples_leaf': 9, 'bootstrap': True, 'max_features': None, 'criterion': 'gini', 'min_impurity_decrease': 0.006919079660824813}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:01:27,601] Trial 30 finished with value: 0.8651745497825202 and parameters: {'n_estimators': 108, 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 10, 'bootstrap': True, 'max_features': None, 'criterion': 'gini', 'min_impurity_decrease': 0.028472746588402854}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:01:40,440] Trial 31 finished with value: 0.8764873825276973 and parameters: {'n_estimators': 455, 'max_depth': 7, 'min_samples_split': 11, 'min_samples_leaf': 9, 'bootstrap': True, 'max_features': None, 'criterion': 'gini', 'min_impurity_decrease': 0.007942976154040543}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:01:51,828] Trial 32 finished with value: 0.8764873825276973 and parameters: {'n_estimators': 400, 'max_depth': 9, 'min_samples_split': 13, 'min_samples_leaf': 9, 'bootstrap': True, 'max_features': None, 'criterion': 'gini', 'min_impurity_decrease': 0.0071194446267498525}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:02:04,059] Trial 33 finished with value: 0.8651745497825202 and parameters: {'n_estimators': 448, 'max_depth': 6, 'min_samples_split': 13, 'min_samples_leaf': 7, 'bootstrap': True, 'max_features': None, 'criterion': 'gini', 'min_impurity_decrease': 0.021289534380700994}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:02:14,560] Trial 34 finished with value: 0.8490348248053727 and parameters: {'n_estimators': 394, 'max_depth': 3, 'min_samples_split': 11, 'min_samples_leaf': 11, 'bootstrap': False, 'max_features': None, 'criterion': 'gini', 'min_impurity_decrease': 0.006119300038184613}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:02:28,947] Trial 35 finished with value: 0.8773343961771303 and parameters: {'n_estimators': 470, 'max_depth': 19, 'min_samples_split': 9, 'min_samples_leaf': 10, 'bootstrap': True, 'max_features': None, 'criterion': 'entropy', 'min_impurity_decrease': 0.018465383816575618}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:02:42,753] Trial 36 finished with value: 0.8651745497825202 and parameters: {'n_estimators': 469, 'max_depth': 20, 'min_samples_split': 8, 'min_samples_leaf': 10, 'bootstrap': False, 'max_features': None, 'criterion': 'entropy', 'min_impurity_decrease': 0.019530126883948215}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:02:55,259] Trial 37 finished with value: 0.8651745497825202 and parameters: {'n_estimators': 411, 'max_depth': 13, 'min_samples_split': 9, 'min_samples_leaf': 11, 'bootstrap': True, 'max_features': None, 'criterion': 'entropy', 'min_impurity_decrease': 0.036032352515380096}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:03:06,991] Trial 38 finished with value: 0.8541757084407997 and parameters: {'n_estimators': 380, 'max_depth': 4, 'min_samples_split': 8, 'min_samples_leaf': 7, 'bootstrap': False, 'max_features': None, 'criterion': 'entropy', 'min_impurity_decrease': 0.0170771309155113}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:03:14,094] Trial 39 finished with value: 0.8690941218831497 and parameters: {'n_estimators': 197, 'max_depth': 25, 'min_samples_split': 5, 'min_samples_leaf': 3, 'bootstrap': True, 'max_features': None, 'criterion': 'entropy', 'min_impurity_decrease': 0.004500567380824154}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:03:29,507] Trial 40 finished with value: 0.8651745497825202 and parameters: {'n_estimators': 500, 'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 8, 'bootstrap': False, 'max_features': None, 'criterion': 'entropy', 'min_impurity_decrease': 0.024416601505509013}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:03:44,839] Trial 41 finished with value: 0.8761886883315941 and parameters: {'n_estimators': 454, 'max_depth': 18, 'min_samples_split': 12, 'min_samples_leaf': 9, 'bootstrap': True, 'max_features': None, 'criterion': 'entropy', 'min_impurity_decrease': 0.006432026222724074}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:03:54,042] Trial 42 finished with value: 0.8740473940912057 and parameters: {'n_estimators': 457, 'max_depth': 22, 'min_samples_split': 10, 'min_samples_leaf': 10, 'bootstrap': True, 'max_features': 'log2', 'criterion': 'gini', 'min_impurity_decrease': 0.010966643412637648}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:04:08,540] Trial 43 finished with value: 0.87697244534519 and parameters: {'n_estimators': 473, 'max_depth': 10, 'min_samples_split': 15, 'min_samples_leaf': 12, 'bootstrap': True, 'max_features': None, 'criterion': 'gini', 'min_impurity_decrease': 0.0017840633844528712}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:04:24,961] Trial 44 finished with value: 0.8794291766568284 and parameters: {'n_estimators': 478, 'max_depth': 10, 'min_samples_split': 15, 'min_samples_leaf': 12, 'bootstrap': True, 'max_features': None, 'criterion': 'entropy', 'min_impurity_decrease': 0.0006332473214668696}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:04:38,963] Trial 45 finished with value: 0.8761093775489519 and parameters: {'n_estimators': 422, 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 11, 'bootstrap': True, 'max_features': None, 'criterion': 'entropy', 'min_impurity_decrease': 6.533714453986809e-05}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:04:49,048] Trial 46 finished with value: 0.8706755711101637 and parameters: {'n_estimators': 482, 'max_depth': 11, 'min_samples_split': 15, 'min_samples_leaf': 13, 'bootstrap': True, 'max_features': 'log2', 'criterion': 'entropy', 'min_impurity_decrease': 0.015772553666612635}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:04:55,875] Trial 47 finished with value: 0.8651745497825202 and parameters: {'n_estimators': 228, 'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 6, 'bootstrap': True, 'max_features': None, 'criterion': 'entropy', 'min_impurity_decrease': 0.04329659031053015}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:05:01,541] Trial 48 finished with value: 0.8701413356751606 and parameters: {'n_estimators': 274, 'max_depth': 32, 'min_samples_split': 11, 'min_samples_leaf': 2, 'bootstrap': True, 'max_features': 'log2', 'criterion': 'entropy', 'min_impurity_decrease': 0.03188806591921278}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:05:10,448] Trial 49 finished with value: 0.8651745497825202 and parameters: {'n_estimators': 368, 'max_depth': 8, 'min_samples_split': 6, 'min_samples_leaf': 13, 'bootstrap': False, 'max_features': None, 'criterion': 'entropy', 'min_impurity_decrease': 0.09785889974426176}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:05:19,526] Trial 50 finished with value: 0.8651745497825202 and parameters: {'n_estimators': 324, 'max_depth': 2, 'min_samples_split': 15, 'min_samples_leaf': 5, 'bootstrap': True, 'max_features': None, 'criterion': 'entropy', 'min_impurity_decrease': 0.08939923081207435}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:05:33,699] Trial 51 finished with value: 0.8765217580396639 and parameters: {'n_estimators': 474, 'max_depth': 10, 'min_samples_split': 15, 'min_samples_leaf': 12, 'bootstrap': True, 'max_features': None, 'criterion': 'gini', 'min_impurity_decrease': 0.0020821954896218095}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:05:46,502] Trial 52 finished with value: 0.8766801681779128 and parameters: {'n_estimators': 433, 'max_depth': 9, 'min_samples_split': 16, 'min_samples_leaf': 12, 'bootstrap': True, 'max_features': None, 'criterion': 'gini', 'min_impurity_decrease': 0.003222107953392719}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:06:00,307] Trial 53 finished with value: 0.8746798161515903 and parameters: {'n_estimators': 491, 'max_depth': 12, 'min_samples_split': 15, 'min_samples_leaf': 11, 'bootstrap': True, 'max_features': None, 'criterion': 'gini', 'min_impurity_decrease': 0.010581003269820043}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:06:12,517] Trial 54 finished with value: 0.8663725726261783 and parameters: {'n_estimators': 439, 'max_depth': 14, 'min_samples_split': 13, 'min_samples_leaf': 13, 'bootstrap': True, 'max_features': None, 'criterion': 'gini', 'min_impurity_decrease': 0.015712259143767206}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:06:24,363] Trial 55 finished with value: 0.8770995996116886 and parameters: {'n_estimators': 407, 'max_depth': 10, 'min_samples_split': 16, 'min_samples_leaf': 10, 'bootstrap': True, 'max_features': None, 'criterion': 'gini', 'min_impurity_decrease': 0.0035955468084045055}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:06:33,295] Trial 56 finished with value: 0.8770925827259847 and parameters: {'n_estimators': 411, 'max_depth': 27, 'min_samples_split': 16, 'min_samples_leaf': 8, 'bootstrap': True, 'max_features': 'sqrt', 'criterion': 'gini', 'min_impurity_decrease': 0.004276262613553088}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:06:43,644] Trial 57 finished with value: 0.8545472372314075 and parameters: {'n_estimators': 470, 'max_depth': 7, 'min_samples_split': 14, 'min_samples_leaf': 10, 'bootstrap': True, 'max_features': 'log2', 'criterion': 'entropy', 'min_impurity_decrease': 0.06593731415718172}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:06:46,519] Trial 58 finished with value: 0.8690646851632563 and parameters: {'n_estimators': 134, 'max_depth': 12, 'min_samples_split': 16, 'min_samples_leaf': 1, 'bootstrap': True, 'max_features': 'sqrt', 'criterion': 'gini', 'min_impurity_decrease': 0.011273276278763879}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:06:47,633] Trial 59 finished with value: 0.8627386940141598 and parameters: {'n_estimators': 48, 'max_depth': 15, 'min_samples_split': 11, 'min_samples_leaf': 11, 'bootstrap': True, 'max_features': 'sqrt', 'criterion': 'gini', 'min_impurity_decrease': 0.015611649964506893}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:07:02,237] Trial 60 finished with value: 0.8727179632681272 and parameters: {'n_estimators': 498, 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 2, 'bootstrap': True, 'max_features': None, 'criterion': 'gini', 'min_impurity_decrease': 0.009667542415192392}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:07:11,865] Trial 61 finished with value: 0.8795580595894265 and parameters: {'n_estimators': 413, 'max_depth': 26, 'min_samples_split': 16, 'min_samples_leaf': 7, 'bootstrap': True, 'max_features': 'sqrt', 'criterion': 'gini', 'min_impurity_decrease': 0.004668033868236334}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:07:21,802] Trial 62 finished with value: 0.8757709183042888 and parameters: {'n_estimators': 411, 'max_depth': 24, 'min_samples_split': 16, 'min_samples_leaf': 7, 'bootstrap': True, 'max_features': 'sqrt', 'criterion': 'gini', 'min_impurity_decrease': 0.0002952418832132277}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:07:30,896] Trial 63 finished with value: 0.8755996084871089 and parameters: {'n_estimators': 433, 'max_depth': 30, 'min_samples_split': 14, 'min_samples_leaf': 5, 'bootstrap': True, 'max_features': 'sqrt', 'criterion': 'gini', 'min_impurity_decrease': 0.0039969110111433325}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:07:37,294] Trial 64 finished with value: 0.8696703256324039 and parameters: {'n_estimators': 268, 'max_depth': 19, 'min_samples_split': 8, 'min_samples_leaf': 8, 'bootstrap': True, 'max_features': 'sqrt', 'criterion': 'gini', 'min_impurity_decrease': 0.006072445241029574}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:07:44,994] Trial 65 finished with value: 0.8690036355011823 and parameters: {'n_estimators': 368, 'max_depth': 26, 'min_samples_split': 16, 'min_samples_leaf': 9, 'bootstrap': True, 'max_features': 'sqrt', 'criterion': 'gini', 'min_impurity_decrease': 0.013131100992435207}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:07:54,608] Trial 66 finished with value: 0.8680497694096612 and parameters: {'n_estimators': 444, 'max_depth': 17, 'min_samples_split': 15, 'min_samples_leaf': 4, 'bootstrap': True, 'max_features': 'sqrt', 'criterion': 'gini', 'min_impurity_decrease': 0.01767415027074915}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:08:04,813] Trial 67 finished with value: 0.8669889987302465 and parameters: {'n_estimators': 463, 'max_depth': 22, 'min_samples_split': 10, 'min_samples_leaf': 7, 'bootstrap': True, 'max_features': 'sqrt', 'criterion': 'gini', 'min_impurity_decrease': 0.022768751127611446}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:08:18,526] Trial 68 finished with value: 0.82942370552152 and parameters: {'n_estimators': 390, 'max_depth': 11, 'min_samples_split': 16, 'min_samples_leaf': 10, 'bootstrap': False, 'max_features': None, 'criterion': 'entropy', 'min_impurity_decrease': 0.008628773217258514}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:08:22,282] Trial 69 finished with value: 0.8727892305901366 and parameters: {'n_estimators': 185, 'max_depth': 9, 'min_samples_split': 12, 'min_samples_leaf': 6, 'bootstrap': True, 'max_features': 'sqrt', 'criterion': 'gini', 'min_impurity_decrease': 0.014292532256238409}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:08:34,734] Trial 70 finished with value: 0.8651745497825202 and parameters: {'n_estimators': 485, 'max_depth': 13, 'min_samples_split': 14, 'min_samples_leaf': 9, 'bootstrap': True, 'max_features': None, 'criterion': 'gini', 'min_impurity_decrease': 0.054209756966818574}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:08:44,446] Trial 71 finished with value: 0.8740683891775977 and parameters: {'n_estimators': 413, 'max_depth': 27, 'min_samples_split': 16, 'min_samples_leaf': 8, 'bootstrap': True, 'max_features': 'sqrt', 'criterion': 'gini', 'min_impurity_decrease': 0.004910654471469204}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:08:53,514] Trial 72 finished with value: 0.8734777793307764 and parameters: {'n_estimators': 407, 'max_depth': 10, 'min_samples_split': 15, 'min_samples_leaf': 8, 'bootstrap': True, 'max_features': 'sqrt', 'criterion': 'gini', 'min_impurity_decrease': 0.0048951010303249715}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:09:00,154] Trial 73 finished with value: 0.8710217685867667 and parameters: {'n_estimators': 306, 'max_depth': 20, 'min_samples_split': 16, 'min_samples_leaf': 10, 'bootstrap': True, 'max_features': 'sqrt', 'criterion': 'gini', 'min_impurity_decrease': 0.008963993675966618}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:09:10,326] Trial 74 finished with value: 0.8710052685477134 and parameters: {'n_estimators': 419, 'max_depth': 28, 'min_samples_split': 15, 'min_samples_leaf': 7, 'bootstrap': True, 'max_features': 'sqrt', 'criterion': 'gini', 'min_impurity_decrease': 7.615739936531717e-05}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:09:19,659] Trial 75 finished with value: 0.8738619774787798 and parameters: {'n_estimators': 445, 'max_depth': 24, 'min_samples_split': 16, 'min_samples_leaf': 9, 'bootstrap': True, 'max_features': 'sqrt', 'criterion': 'gini', 'min_impurity_decrease': 0.0028227522949490396}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:09:25,589] Trial 76 finished with value: 0.8755668795637408 and parameters: {'n_estimators': 241, 'max_depth': 30, 'min_samples_split': 2, 'min_samples_leaf': 10, 'bootstrap': True, 'max_features': 'sqrt', 'criterion': 'entropy', 'min_impurity_decrease': 0.007442977270022374}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:09:36,377] Trial 77 finished with value: 0.8651745497825202 and parameters: {'n_estimators': 397, 'max_depth': 21, 'min_samples_split': 10, 'min_samples_leaf': 8, 'bootstrap': True, 'max_features': None, 'criterion': 'gini', 'min_impurity_decrease': 0.0199201461099398}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:09:45,495] Trial 78 finished with value: 0.8679932722345202 and parameters: {'n_estimators': 465, 'max_depth': 16, 'min_samples_split': 13, 'min_samples_leaf': 7, 'bootstrap': True, 'max_features': 'log2', 'criterion': 'gini', 'min_impurity_decrease': 0.012467147130494606}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:09:59,405] Trial 79 finished with value: 0.8691398702142278 and parameters: {'n_estimators': 430, 'max_depth': 18, 'min_samples_split': 9, 'min_samples_leaf': 15, 'bootstrap': True, 'max_features': None, 'criterion': 'entropy', 'min_impurity_decrease': 0.003515519470625582}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:10:05,704] Trial 80 finished with value: 0.85709474700069 and parameters: {'n_estimators': 376, 'max_depth': 26, 'min_samples_split': 14, 'min_samples_leaf': 9, 'bootstrap': False, 'max_features': 'sqrt', 'criterion': 'gini', 'min_impurity_decrease': 0.07936953781927547}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:10:20,278] Trial 81 finished with value: 0.8785380916751807 and parameters: {'n_estimators': 485, 'max_depth': 10, 'min_samples_split': 15, 'min_samples_leaf': 12, 'bootstrap': True, 'max_features': None, 'criterion': 'gini', 'min_impurity_decrease': 0.002154068120858909}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:10:34,034] Trial 82 finished with value: 0.8790518453945795 and parameters: {'n_estimators': 482, 'max_depth': 9, 'min_samples_split': 15, 'min_samples_leaf': 14, 'bootstrap': True, 'max_features': None, 'criterion': 'gini', 'min_impurity_decrease': 0.004857055980366854}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:10:47,707] Trial 83 finished with value: 0.8746970982114425 and parameters: {'n_estimators': 484, 'max_depth': 9, 'min_samples_split': 15, 'min_samples_leaf': 15, 'bootstrap': True, 'max_features': None, 'criterion': 'gini', 'min_impurity_decrease': 0.0067058940665753655}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:11:01,138] Trial 84 finished with value: 0.8771554037947482 and parameters: {'n_estimators': 481, 'max_depth': 11, 'min_samples_split': 15, 'min_samples_leaf': 14, 'bootstrap': True, 'max_features': None, 'criterion': 'gini', 'min_impurity_decrease': 0.01004564467216175}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:11:14,862] Trial 85 finished with value: 0.8771164767132509 and parameters: {'n_estimators': 500, 'max_depth': 8, 'min_samples_split': 14, 'min_samples_leaf': 14, 'bootstrap': True, 'max_features': None, 'criterion': 'gini', 'min_impurity_decrease': 0.009930073905984757}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:11:29,840] Trial 86 finished with value: 0.8738868324813513 and parameters: {'n_estimators': 477, 'max_depth': 11, 'min_samples_split': 15, 'min_samples_leaf': 13, 'bootstrap': True, 'max_features': None, 'criterion': 'entropy', 'min_impurity_decrease': 0.011130723724170536}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:11:42,189] Trial 87 finished with value: 0.8651745497825202 and parameters: {'n_estimators': 456, 'max_depth': 14, 'min_samples_split': 13, 'min_samples_leaf': 14, 'bootstrap': True, 'max_features': None, 'criterion': 'gini', 'min_impurity_decrease': 0.017560467868666853}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:11:54,837] Trial 88 finished with value: 0.8651745497825202 and parameters: {'n_estimators': 486, 'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 15, 'bootstrap': True, 'max_features': None, 'criterion': 'gini', 'min_impurity_decrease': 0.025303946921721752}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:12:09,563] Trial 89 finished with value: 0.8733373847567979 and parameters: {'n_estimators': 463, 'max_depth': 11, 'min_samples_split': 8, 'min_samples_leaf': 13, 'bootstrap': True, 'max_features': None, 'criterion': 'entropy', 'min_impurity_decrease': 0.0018874822495695822}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:12:23,075] Trial 90 finished with value: 0.8778393638796788 and parameters: {'n_estimators': 474, 'max_depth': 13, 'min_samples_split': 11, 'min_samples_leaf': 11, 'bootstrap': True, 'max_features': None, 'criterion': 'gini', 'min_impurity_decrease': 0.007136167887511452}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:12:36,535] Trial 91 finished with value: 0.8792335946489095 and parameters: {'n_estimators': 478, 'max_depth': 12, 'min_samples_split': 11, 'min_samples_leaf': 11, 'bootstrap': True, 'max_features': None, 'criterion': 'gini', 'min_impurity_decrease': 0.006909310028858366}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:12:49,275] Trial 92 finished with value: 0.8796078124971567 and parameters: {'n_estimators': 445, 'max_depth': 12, 'min_samples_split': 11, 'min_samples_leaf': 12, 'bootstrap': True, 'max_features': None, 'criterion': 'gini', 'min_impurity_decrease': 0.006698716832491222}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:13:01,921] Trial 93 finished with value: 0.8760536495939644 and parameters: {'n_estimators': 446, 'max_depth': 13, 'min_samples_split': 11, 'min_samples_leaf': 11, 'bootstrap': True, 'max_features': None, 'criterion': 'gini', 'min_impurity_decrease': 0.006977034557334758}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:13:14,931] Trial 94 finished with value: 0.8728291011722591 and parameters: {'n_estimators': 472, 'max_depth': 15, 'min_samples_split': 11, 'min_samples_leaf': 12, 'bootstrap': True, 'max_features': None, 'criterion': 'gini', 'min_impurity_decrease': 0.014195562921770002}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:13:28,201] Trial 95 finished with value: 0.8778615591984842 and parameters: {'n_estimators': 461, 'max_depth': 12, 'min_samples_split': 12, 'min_samples_leaf': 12, 'bootstrap': True, 'max_features': None, 'criterion': 'gini', 'min_impurity_decrease': 0.00611424153069699}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:13:41,228] Trial 96 finished with value: 0.8787279622884384 and parameters: {'n_estimators': 453, 'max_depth': 12, 'min_samples_split': 12, 'min_samples_leaf': 12, 'bootstrap': True, 'max_features': None, 'criterion': 'gini', 'min_impurity_decrease': 0.006136501830876986}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:13:54,736] Trial 97 finished with value: 0.8310649550795158 and parameters: {'n_estimators': 440, 'max_depth': 10, 'min_samples_split': 12, 'min_samples_leaf': 12, 'bootstrap': False, 'max_features': None, 'criterion': 'gini', 'min_impurity_decrease': 0.0021124005934216343}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:14:08,943] Trial 98 finished with value: 0.8753634885005775 and parameters: {'n_estimators': 457, 'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 12, 'bootstrap': True, 'max_features': None, 'criterion': 'gini', 'min_impurity_decrease': 0.00029721296977663827}. Best is trial 24 with value: 0.8799526844610203.
# [I 2025-01-03 16:14:23,209] Trial 99 finished with value: 0.8774478803631951 and parameters: {'n_estimators': 493, 'max_depth': 12, 'min_samples_split': 12, 'min_samples_leaf': 11, 'bootstrap': True, 'max_features': None, 'criterion': 'gini', 'min_impurity_decrease': 0.005562174827581887}. Best is trial 24 with value: 0.8799526844610203.
# Random Forest - Melhores Hiperparâmetros: {'n_estimators': 243, 'max_depth': 21, 'min_samples_split': 10, 'min_samples_leaf': 6, 'bootstrap': True, 'max_features': 'sqrt', 'criterion': 'gini', 'min_impurity_decrease': 0.007954109350970642}
# Random Forest - Melhor F1 Score: 0.8799526844610203

# %% [markdown]
# ###**Ajustando o modelo com os melhores parametros**

# %% [markdown]
# Abaixo temos os melhores parâmetros capturados no processo anterior.

# %%
melhores_parametros = {'n_estimators': 332,
                       'max_depth': 12,
                       'min_samples_split': 10,
                       'min_samples_leaf': 10,
                       'bootstrap': True,
                       'max_features': None,
                       'criterion': 'entropy',
                       'min_impurity_decrease': 0.01550720051004077}

# %% [markdown]
# E finalmente iremos fazer o treinamento. Aqui estamos utilizando os parametros escolhidos anteriormente, utilizamos o random_state para garantir a reprodutibilidade dos dados.

# %%
rf_clf = RandomForestClassifier(**melhores_parametros, random_state=42)

rf_clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=12, max_features=None,
#                        min_impurity_decrease=0.01550720051004077,
#                        min_samples_leaf=10, min_samples_split=10,
#                        n_estimators=332, random_state=42)

# %%
y_pred_rf = rf_clf.predict(X_test)

print("Random Forest - Relatório de Classificação (Conjunto de Teste):")
print(classification_report(y_test, y_pred_rf))

print("Random Forest - Matriz de Confusão (Conjunto de Teste):")
print(confusion_matrix(y_test, y_pred_rf))
# Out:
# Random Forest - Relatório de Classificação (Conjunto de Teste):
#               precision    recall  f1-score   support
#
#            0       0.87      0.88      0.88        77
#            1       0.88      0.87      0.88        77
#
#     accuracy                           0.88       154
#    macro avg       0.88      0.88      0.88       154
# weighted avg       0.88      0.88      0.88       154
#
# Random Forest - Matriz de Confusão (Conjunto de Teste):
# [[68  9]
#  [10 67]]

# %% [markdown]
# Iremos observar algumas metricas do modelo, começando pela matriz de confusão.

# %%
cm = confusion_matrix(y_test, y_pred_rf)

plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Purples', cbar=False)
plt.xlabel('Predição')
plt.ylabel('Real')
plt.title('Matriz de Confusão - Random Forest')
plt.show()

# %% [markdown]
# O desempenho geral do modelo é bom, com alta precisão e recall, significando que consegue classificar bem a maioria dos positivos quanto a maioria dos negativos.

# %% [markdown]
# Abaixo iremos observar a curva ROC, com ela é ilustrada a performance do modelo, plotando a taxa de verdadeiros positivos contra a taxa de falsos positivos.

# %%
y_prob_rf = rf_clf.predict_proba(X_test)[:, 1]

fpr, tpr, thresholds = roc_curve(y_test, y_prob_rf)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='blue', lw=2, label='Curva ROC (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='orange', lw=2, linestyle='--', label='Classificador Aleatório')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Taxa de Falsos Positivos')
plt.ylabel('Taxa de Verdadeiros Positivos')
plt.title('Curva ROC - Random Forest')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

# %% [markdown]
# - O desempenho do modelo se moostra bom na classificação das categorias.
# - Com um AUC de 0.94 é um boa confiança para um modelo eficaz no propósito.

# %%
accuracy = accuracy_score(y_test, y_pred_rf)
precision = precision_score(y_test, y_pred_rf)
recall = recall_score(y_test, y_pred_rf)
f1 = f1_score(y_test, y_pred_rf)
roc_auc = roc_auc_score(y_test, y_prob_rf)
brier = brier_score_loss(y_test, y_prob_rf)

fpr, tpr, thresholds = roc_curve(y_test, y_prob_rf)
gini = 2 * roc_auc - 1

precision_vals, recall_vals, _ = precision_recall_curve(y_test, y_prob_rf)
pr_auc = auc(recall_vals, precision_vals)

metrics = {
    'Metric': ['Accuracy', 'Precision', 'Recall', 'F1-Score', 'ROC-AUC', 'Gini', 'PR-AUC', 'Brier'],
    'Value': [accuracy, precision, recall, f1, roc_auc, gini, pr_auc, brier]
}

df_metrics = pd.DataFrame(metrics)
df_metrics
# Out:
#       Metric     Value
# 0   Accuracy  0.876623
# 1  Precision  0.881579
# 2     Recall  0.870130
# 3   F1-Score  0.875817
# 4    ROC-AUC  0.936583
# 5       Gini  0.873166
# 6     PR-AUC  0.914393
# 7      Brier  0.090697

# %% [markdown]
# - O nosso recall é de 0.87, significando que o modelo consegue identificar 87% das aprovações corretamente. Olhando para a matriz de confusão de 77 ele previu 68 corretamente.
# - A precisão esta em 0.88, conseguindo identificar 88% dos dados. Observando a matriz de 77 dados ele conseguiu prever 69 corretamente.
# - Com o ROC-AUC em 0.938, apresenta uma boa capacidade de diferenciar as pessoas que terão aprovação do cartão das que não terão.

# %% [markdown]
# ##**Resultados financeiros**

# %% [markdown]
# Iremos analisar algumas métricas que podem ser afetadas pelas aprovações e recusas, para isso será usado como base a matriz de confusão. Com isso, iremos acompanhar algumas variáveis, sendo elas:
# - Receita média por cliente aprovado (verdadeiros positivos).
# - Receita dos falsos positivos (quanto de perda), pessoas que não eram para ser aprovadas.
# - Receita dos falsos negativos (quanto de perda), pessoas que eram para ser aprovadas.
#
# Importante: Os valores abaixo são fictícios.
#
# Abaixo estaremos pegando os valores da matriz de confusão e definindo quais são os valores referentes à receita de acordo com cada situação.

# %%
VN, FP, FN, VP = cm.ravel()

receita_media_aprovado = 15000
custo_falsos_positivos = 2500
custo_falsos_negativos = 7500

# %%
receita_media_vp = VP * receita_media_aprovado

perda_fp = FP * custo_falsos_positivos

perda_fn = FN * custo_falsos_negativos

print(f"Receita Média por Cliente Aprovado (TP): R${receita_media_vp}")
print(f"Perda por Falsos Positivos (FP): R${perda_fp}")
print(f"Perda por Falsos Negativos (FN): R${perda_fn}")
# Out:
# Receita Média por Cliente Aprovado (TP): R$1005000
# Perda por Falsos Positivos (FP): R$22500
# Perda por Falsos Negativos (FN): R$75000

# %% [markdown]
# ##**Conclusões**
#
# - Foi feito um classificador Random Forest para fazer a previsão da aprovação do cartão de crédito. Tendo como objetivo a construção de um modelo que fosse capaz de fazer a previsão da maioria das situações, com isso, podendo analisar maneiras de aumentar o lucro e reduzir os gastos.
# - O modelo é capaz de prever cerca de 87% dos casos, tendo um desempenho bem solido com a distinção das classes.
# - Foi possível compreender boa parte dos dados, distribuição e correlação utilizando técnicas de EDA.
# - Fazendo uma simulação com dados fictícios ainda podemos ver que consguimos uma boa quantidade de lucro em relação às perdas.
